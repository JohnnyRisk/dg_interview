# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ROOT_DIR = os.getcwd()
BUILDING_DIR = os.path.join(ROOT_DIR, "classification","buildings")
NO_BUILDING_DIR = os.path.join(ROOT_DIR, "classification","no_buildings")
SEG_DIR = os.path.join(ROOT_DIR, "segmentation","images")

# %%
no_buildings = os.listdir(NO_BUILDING_DIR)
shapes=[]
for i in no_buildings:
    img = cv2.imread(os.path.join(NO_BUILDING_DIR,no_buildings[0]),0)
    shapes.append(img.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-28c202b73a29> in <module>()
#       2 shapes=[]
#       3 for i in no_buildings:
# ----> 4     img = cv2.imread(os.path.join(NO_BUILDING_DIR,no_buildings[0]),0)
#       5     shapes.append(img.shape)
#
# KeyboardInterrupt:

# %%
print('Done')

# %%
np.unique(shapes, return_counts=True)
# Out:
# (array([250, 255]), array([5908, 5908]))

# %%
l = [('i',1),('j',2),('a',3)]
f = sorted(l,key=lambda x: x[0])

# %%
f
# Out:
# [('a', 3), ('i', 1), ('j', 2)]

# %%
sorted(l)
# Out:
# [('a', 3), ('i', 1), ('j', 2)]

# %%
os.listdir(SEG_DIR)
# Out:
# ['3857_9_296_285_zimzambot-151858-146099.png',
#  '3857_9_295_278_zimzambot-151199-142816.png',
#  '3857_9_296_285_zimzambot-151829-146049.png',
#  '3857_9_297_282_zimzambot-152305-144732.png',
#  '3857_9_296_282_zimzambot-151715-144826.png',
#  '3857_9_297_282_zimzambot-152230-144489.png',
#  '3857_9_392_230_20160805_587662-200913-118001.png',
#  '3857_9_300_283_zimzambot-153923-145080.png',
#  '3857_9_293_279_zimzambot-150489-143239.png',
#  '3857_9_393_231_20160805_587677-201262-118579.png',
#  '3857_9_299_285_zimzambot-153091-146179.png',
#  '3857_9_293_278_zimzambot-150230-142519.png',
#  '3857_9_293_278_zimzambot-150062-142538.png',
#  '3857_9_306_290_20170129_633977-156833-148769.png',
#  '3857_9_299_283_zimzambot-153498-145318.png',
#  '3857_9_293_278_zimzambot-150245-142728.png',
#  '3857_9_287_282_zimzambot-146979-144694.png',
#  '3857_9_298_284_zimzambot-152960-145903.png',
#  '3857_9_297_282_zimzambot-152265-144421.png',
#  '3857_9_300_283_zimzambot-153823-145099.png',
# ...
